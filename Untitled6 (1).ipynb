# %%
## IMAGE PROCESSING
# !pip install pillow

# %%
# !pip install opencv-python

# %%
## import pillow and openCV
import PIL

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
import zipfile

zip_path = "birds.zip"        # path to zip file
extract_path = "extracted"   # folder to extract into

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("ZIP file extracted successfully")
# Out:
# ZIP file extracted successfully

# %%
import os
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# transforms (common for all 3 models)
transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize([0.5]*3, [0.5]*3)
])

# dataset
dataset = datasets.ImageFolder(root=extract_path, transform=transform)
dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

# %%
# Core
import os
import zipfile
import math

# Numerical
import numpy as np
from tqdm import tqdm

# PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

# Vision
from torchvision import datasets, transforms
from torchvision.utils import save_image

# Image handling
from PIL import Image

# Visualization (optional)
import matplotlib.pyplot as plt

# %%
import torch, torch.nn as nn

autoencoder = nn.Sequential(
    nn.Flatten(),
    nn.Linear(3*64*64, 256),
    nn.ReLU(),
    nn.Linear(256, 3*64*64),
    nn.Unflatten(1, (3,64,64))
)

criterion = nn.MSELoss()

# %%
for x, _ in dataloader:
    recon = autoencoder(x)
    loss = criterion(recon, x)

# %%
G = nn.Sequential(
    nn.Linear(100, 256),
    nn.ReLU(),
    nn.Linear(256, 3*64*64),
    nn.Tanh()
)

D = nn.Sequential(
    nn.Flatten(),
    nn.Linear(3*64*64, 256),
    nn.ReLU(),
    nn.Linear(256, 1),
    nn.Sigmoid()
)

# %%
criterion = nn.BCELoss()
opt_G = optim.Adam(G.parameters(), lr=0.0002)
opt_D = optim.Adam(D.parameters(), lr=0.0002)

# %%
def add_noise(x, t):
    noise = torch.randn_like(x)
    return x + 0.1 * noise, noise

model = nn.Sequential(
    nn.Flatten(),
    nn.Linear(3*64*64, 256),
    nn.ReLU(),
    nn.Linear(256, 3*64*64),
    nn.Unflatten(1, (3,64,64))
)

# %%
t = torch.tensor(0)
noisy, noise = add_noise(x, t)
pred = model(noisy)
loss = ((pred - noise)**2).mean()

# %%
autoencoder.eval()

with torch.no_grad():
    x, _ = next(iter(dataloader))
    recon = autoencoder(x)

print(x.shape, recon.shape)
# Out:
# torch.Size([10, 3, 64, 64]) torch.Size([10, 3, 64, 64])

# %%
from torchvision.utils import save_image
save_image(recon[:8], "ae_output.png", normalize=True)

# %%
z = torch.randn(8, 100)
fake_images = G(z)

save_image(fake_images.view(-1,3,64,64), "gan_output.png", normalize=True)

# %%
x, _ = next(iter(dataloader))
noisy, noise = add_noise(x, t=None)

pred_noise = model(noisy)
print(pred_noise.shape)
# Out:
# torch.Size([10, 3, 64, 64])

# %%
pip install streamlit torch torchvision pillow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 49.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 82.9 MB/s eta 0:00:00
# ...
